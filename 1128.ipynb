# %% [markdown]
# 「批次建立 IP 子資料夾＋複製 AD.xlsx」用程式
#
# 你可以把這支叫做：create_ip_folders_and_copy_ad.py

# %%
from create_ip_folders_and_copy_ad import create_ip_subfolders_and_copy

create_ip_subfolders_and_copy()
# Out:
# 📂 處理 IP01 ...
#    ✅ 建立資料夾 IP01-1 並複製 AD.xlsx
#    ✅ 建立資料夾 IP01-2 並複製 AD.xlsx
#    ✅ 建立資料夾 IP01-3 並複製 AD.xlsx
#    ✅ 建立資料夾 IP01-4 並複製 AD.xlsx
#
# 📂 處理 IP02 ...
#    ✅ 建立資料夾 IP02-1 並複製 AD.xlsx
#    ✅ 建立資料夾 IP02-2 並複製 AD.xlsx
#    ✅ 建立資料夾 IP02-3 並複製 AD.xlsx
#    ✅ 建立資料夾 IP02-4 並複製 AD.xlsx
#
# 📂 處理 IP03 ...
#    ✅ 建立資料夾 IP03-1 並複製 AD.xlsx
#    ✅ 建立資料夾 IP03-2 並複製 AD.xlsx
#    ✅ 建立資料夾 IP03-3 並複製 AD.xlsx
#    ✅ 建立資料夾 IP03-4 並複製 AD.xlsx
#
# 📂 處理 IP05 ...
#    ✅ 建立資料夾 IP05-1 並複製 AD.xlsx
#    ✅ 建立資料夾 IP05-2 並複製 AD.xlsx
#    ✅ 建立資料夾 IP05-3 並複製 AD.xlsx
#    ✅ 建立資料夾 IP05-4 並複製 AD.xlsx
#
# 📂 處理 IP07 ...
#    ✅ 建立資料夾 IP07-1 並複製 AD.xlsx
#    ✅ 建立資料夾 IP07-2 並複製 AD.xlsx
#    ✅ 建立資料夾 IP07-3 並複製 AD.xlsx
#    ✅ 建立資料夾 IP07-4 並複製 AD.xlsx
#
# 📂 處理 IP08 ...
#    ✅ 建立資料夾 IP08-1 並複製 AD.xlsx
#    ✅ 建立資料夾 IP08-2 並複製 AD.xlsx
#    ✅ 建立資料夾 IP08-3 並複製 AD.xlsx
#    ✅ 建立資料夾 IP08-4 並複製 AD.xlsx
#
# 📂 處理 IP10 ...
#    ✅ 建立資料夾 IP10-1 並複製 AD.xlsx
#    ✅ 建立資料夾 IP10-2 並複製 AD.xlsx
#    ✅ 建立資料夾 IP10-3 並複製 AD.xlsx
# ...
